# %% [markdown]
# # **_Step 1 : Importing Libraries_**َ

# %%
# Basic libraries for numerical operations and data handling
import numpy as np
import pandas as pd

# Visualization libraries
import matplotlib.pyplot as plt
import seaborn as sns

# Preprocessing and model evaluation tools
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score

# Classification models
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC

# Suppress warnings for cleaner output
import warnings
warnings.filterwarnings('ignore')

# Styling for plots
plt.style.use('seaborn-v0_8')
sns.set_palette('Set2')

# %% [markdown]
# # **_Step 2: Data Preprocessing_**

# %%
train_df = pd.read_csv(r'C:\Users\pouya\Documents\GitHub\Mobile-Price-Classification-ML\Data\train.csv')
test_df = pd.read_csv(r'C:\Users\pouya\Documents\GitHub\Mobile-Price-Classification-ML\Data\test.csv')

train_df
# Out:
#       battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 0               842     0          2.2         0   1       0           7
# 1              1021     1          0.5         1   0       1          53
# 2               563     1          0.5         1   2       1          41
# 3               615     1          2.5         0   0       0          10
# 4              1821     1          1.2         0  13       1          44
# ...             ...   ...          ...       ...  ..     ...         ...
# 1995            794     1          0.5         1   0       1           2
# 1996           1965     1          2.6         1   0       0          39
# 1997           1911     0          0.9         1   1       1          36
# 1998           1512     0          0.9         0   4       1          46
# 1999            510     1          2.0         1   5       1          45
#
#       m_dep  mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  \
# ...

# %%
test_df
# Out:
#        id  battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 0       1           1043     1          1.8         1  14       0           5
# 1       2            841     1          0.5         1   4       1          61
# 2       3           1807     1          2.8         0   1       0          27
# 3       4           1546     0          0.5         1  18       1          25
# 4       5           1434     0          1.4         0  11       1          49
# ..    ...            ...   ...          ...       ...  ..     ...         ...
# 995   996           1700     1          1.9         0   0       1          54
# 996   997            609     0          1.8         1   0       0          13
# 997   998           1185     0          1.4         0   1       1           8
# 998   999           1533     1          0.5         1   0       0          50
# 999  1000           1270     1          0.5         0   4       1          35
#
# ...

# %%
train_df.head()
# Out:
#    battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  m_dep  \
# 0            842     0          2.2         0   1       0           7    0.6
# 1           1021     1          0.5         1   0       1          53    0.7
# 2            563     1          0.5         1   2       1          41    0.9
# 3            615     1          2.5         0   0       0          10    0.8
# 4           1821     1          1.2         0  13       1          44    0.6
#
#    mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  talk_time  \
# 0        188        2  ...         20       756  2549     9     7         19
# 1        136        3  ...        905      1988  2631    17     3          7
# 2        145        5  ...       1263      1716  2603    11     2          9
# 3        131        6  ...       1216      1786  2769    16     8         11
# 4        141        2  ...       1208      1212  1411     8     2         15
#
# ...

# %%
print('Train dataset shape : ' , train_df.shape)
print('Test dataset shape : ' , test_df.shape)
# Out:
# Train dataset shape :  (2000, 21)
# Test dataset shape :  (1000, 21)

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   battery_power  2000 non-null   int64
#  1   blue           2000 non-null   int64
#  2   clock_speed    2000 non-null   float64
#  3   dual_sim       2000 non-null   int64
#  4   fc             2000 non-null   int64
#  5   four_g         2000 non-null   int64
#  6   int_memory     2000 non-null   int64
#  7   m_dep          2000 non-null   float64
#  8   mobile_wt      2000 non-null   int64
#  9   n_cores        2000 non-null   int64
#  10  pc             2000 non-null   int64
#  11  px_height      2000 non-null   int64
#  12  px_width       2000 non-null   int64
#  13  ram            2000 non-null   int64
#  14  sc_h           2000 non-null   int64
#  15  sc_w           2000 non-null   int64
#  16  talk_time      2000 non-null   int64
#  17  three_g        2000 non-null   int64
# ...

# %%
# Check for missing values
print("Missing values in train dataset:\n", train_df.isnull().sum())
print("\nMissing values in test dataset:\n", test_df.isnull().sum())
# Out:
# Missing values in train dataset:
#  battery_power    0
# blue             0
# clock_speed      0
# dual_sim         0
# fc               0
# four_g           0
# int_memory       0
# m_dep            0
# mobile_wt        0
# n_cores          0
# pc               0
# px_height        0
# px_width         0
# ram              0
# sc_h             0
# sc_w             0
# talk_time        0
# three_g          0
# touch_screen     0
# wifi             0
# price_range      0
# dtype: int64
#
# Missing values in test dataset:
#  id               0
# battery_power    0
# blue             0
# clock_speed      0
# dual_sim         0
# fc               0
# four_g           0
# int_memory       0
# m_dep            0
# mobile_wt        0
# n_cores          0
# pc               0
# px_height        0
# px_width         0
# ram              0
# sc_h             0
# sc_w             0
# talk_time        0
# three_g          0
# touch_screen     0
# wifi             0
# dtype: int64

# %%
# Statistical summary of numerical features
train_df.describe().T
# Out:
#                 count        mean          std    min      25%     50%  \
# battery_power  2000.0  1238.51850   439.418206  501.0   851.75  1226.0
# blue           2000.0     0.49500     0.500100    0.0     0.00     0.0
# clock_speed    2000.0     1.52225     0.816004    0.5     0.70     1.5
# dual_sim       2000.0     0.50950     0.500035    0.0     0.00     1.0
# fc             2000.0     4.30950     4.341444    0.0     1.00     3.0
# four_g         2000.0     0.52150     0.499662    0.0     0.00     1.0
# int_memory     2000.0    32.04650    18.145715    2.0    16.00    32.0
# m_dep          2000.0     0.50175     0.288416    0.1     0.20     0.5
# mobile_wt      2000.0   140.24900    35.399655   80.0   109.00   141.0
# n_cores        2000.0     4.52050     2.287837    1.0     3.00     4.0
# pc             2000.0     9.91650     6.064315    0.0     5.00    10.0
# px_height      2000.0   645.10800   443.780811    0.0   282.75   564.0
# ...

# %%
train_df.columns
# Out:
# Index(['battery_power', 'blue', 'clock_speed', 'dual_sim', 'fc', 'four_g',
#        'int_memory', 'm_dep', 'mobile_wt', 'n_cores', 'pc', 'px_height',
#        'px_width', 'ram', 'sc_h', 'sc_w', 'talk_time', 'three_g',
#        'touch_screen', 'wifi', 'price_range'],
#       dtype='object')

# %%
test_df.columns
# Out:
# Index(['id', 'battery_power', 'blue', 'clock_speed', 'dual_sim', 'fc',
#        'four_g', 'int_memory', 'm_dep', 'mobile_wt', 'n_cores', 'pc',
#        'px_height', 'px_width', 'ram', 'sc_h', 'sc_w', 'talk_time', 'three_g',
#        'touch_screen', 'wifi'],
#       dtype='object')

# %% [markdown]
# # **_Step 3: Exploratory Data Analysis (EDA)_**
# In this section, we’ll explore the dataset feature by feature using various visualizations to better understand distributions, outliers, and relationships to the target variable price_range.

# %%
sns.countplot(x='price_range', data=train_df, palette='Set2')
plt.title("Distribution of Target: Price Range")
plt.xlabel("Price Range")
plt.ylabel("Count")
plt.show()

# %%
binary_cols = ['blue', 'dual_sim', 'four_g', 'three_g', 'touch_screen', 'wifi']
colors = ['Set1', 'Set2', 'Set3', 'pastel', 'husl', 'coolwarm']

# %%
# Countplots
plt.figure(figsize=(15, 10))
for i, col in enumerate(binary_cols):
    plt.subplot(2, 3, i + 1)
    sns.countplot(x=train_df[col], palette=colors[i % len(colors)])
    plt.title(f"{col} Count")
plt.tight_layout()
plt.show()

# %%
# Barplots vs price_range
plt.figure(figsize=(15, 10))
for i, col in enumerate(binary_cols):
    plt.subplot(2, 3, i + 1)
    sns.barplot(x=col, y='price_range', data=train_df, palette=colors[i % len(colors)])
    plt.title(f"{col} vs Price Range")
plt.tight_layout()
plt.show()

# %%
sns.countplot(x='n_cores', data=train_df, palette='Set1')
plt.title("Number of CPU Cores")
plt.show()

# %%
sns.barplot(x='n_cores', y='price_range', data=train_df, palette='cubehelix')
plt.title("n_cores vs Price Range")
plt.show()

# %%
numeric_cols = [
    'battery_power', 'clock_speed', 'fc', 'int_memory', 'm_dep', 'mobile_wt',
    'pc', 'px_height', 'px_width', 'ram', 'sc_h', 'sc_w', 'talk_time'
]

# %%
plt.figure(figsize=(18, 12))
for i, col in enumerate(numeric_cols):
    plt.subplot(4, 4, i + 1)
    sns.histplot(train_df[col], kde=True, bins=30, color=sns.color_palette("husl", 16)[i])
    plt.title(f"{col} Distribution")
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(18, 12))
for i, col in enumerate(numeric_cols):
    plt.subplot(4, 4, i + 1)
    sns.boxplot(x='price_range', y=col, data=train_df, palette='pastel')
    plt.title(f"{col} vs Price Range")
plt.tight_layout()
plt.show()

# %%
sns.violinplot(x='price_range', y='ram', data=train_df, palette='Set3')
plt.title("RAM vs Price Range")
plt.show()

# %%
sns.violinplot(x='price_range', y='battery_power', data=train_df, palette='coolwarm')
plt.title("Battery Power vs Price Range")
plt.show()

# %%
outlier_cols = ['fc', 'pc', 'px_height', 'px_width', 'ram', 'int_memory']

# %%
plt.figure(figsize=(15, 10))
for i, col in enumerate(outlier_cols):
    plt.subplot(2, 3, i + 1)
    sns.boxplot(y=train_df[col], color=sns.color_palette("Set2")[i % 8])
    plt.title(f"{col} - Outliers")
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize = (20,15))
sns.scatterplot(x='px_width', y='px_height', hue='price_range', data=train_df, palette='Set1')
plt.title("Pixel Width vs Height (by Price Range)")
plt.show()

# %%
plt.figure(figsize=(16, 12))
corr = train_df.corr()
sns.heatmap(corr, annot=True, cmap='coolwarm', fmt='.2f', linewidths=0.5)
plt.title("Correlation Heatmap")
plt.show()

# %% [markdown]
# # Step 4: Basic Modeling
#
# We will train three classification models (Decision Tree, Random Forest, SVM) without any tuning. The goal is to get a baseline performance for comparison.

# %% [markdown]
# ## 4.1: Decision Tree Classifier (Baseline)
#
# We start with a simple Decision Tree classifier using default parameters.

# %%
# Feature/Target split
X = train_df.drop('price_range', axis=1)
y = train_df['price_range']

# Different test sizes
test_sizes = [0.1, 0.15, 0.2, 0.25, 0.3, 0.35, 0.4]
accuracies = {}

# %%
# Loop over test sizes
for size in test_sizes:
    # Train/test split
    X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=size, random_state=42, stratify=y)

    # Train model
    model = DecisionTreeClassifier(random_state=42)
    model.fit(X_train, y_train)

    # Predict
    y_pred = model.predict(X_val)

    # Accuracy
    acc = accuracy_score(y_val, y_pred)
    accuracies[size] = acc
    print(f"Test size = {int(size*100)}% | Accuracy = {acc:.4f}")
# Out:
# Test size = 10% | Accuracy = 0.8150
# Test size = 15% | Accuracy = 0.8400
# Test size = 20% | Accuracy = 0.8300
# Test size = 25% | Accuracy = 0.8240
# Test size = 30% | Accuracy = 0.8167
# Test size = 35% | Accuracy = 0.8114
# Test size = 40% | Accuracy = 0.8125

# %%
# Find best test size
best_size = max(accuracies, key=accuracies.get)
print(f"\nBest test size: {int(best_size*100)}%")

# Re-split with best size
X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=best_size, random_state=42, stratify=y)
# Out:
# Best test size: 15%

# %%
# Retrain best model
best_model = DecisionTreeClassifier(random_state=42)
best_model.fit(X_train, y_train)
y_pred_best = best_model.predict(X_val)

# %%
cm = confusion_matrix(y_val, y_pred_best)
plt.figure(figsize=(6, 5))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=best_model.classes_, yticklabels=best_model.classes_)
plt.title(f"Confusion Matrix (Test size: {int(best_size*100)}%)")
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.show()

# %%
# Classification Report
print("\nClassification Report:\n", classification_report(y_val, y_pred_best))
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.91      0.93      0.92        75
#            1       0.81      0.80      0.81        75
#            2       0.75      0.77      0.76        75
#            3       0.89      0.85      0.87        75
#
#     accuracy                           0.84       300
#    macro avg       0.84      0.84      0.84       300
# weighted avg       0.84      0.84      0.84       300

# %%
from sklearn.tree import plot_tree

plt.figure(figsize=(20,10))
plot_tree(best_model, filled=True, feature_names=X.columns, class_names=['Low', 'Medium', 'High', 'Very High'], max_depth=2)
plt.title("Visualized Decision Tree (depth=2)")
plt.show()

# %%
# Plot feature importances
feat_imp = pd.Series(best_model.feature_importances_, index=X.columns)
feat_imp = feat_imp.sort_values(ascending=False)

plt.figure(figsize=(10,6))
sns.barplot(x=feat_imp, y=feat_imp.index, palette="viridis")
plt.title("Decision Tree - Feature Importance")
plt.xlabel("Importance Score")
plt.ylabel("Features")
plt.tight_layout()
plt.show()

# %% [markdown]
# ✅ **_Summary_**:
#
# The Decision Tree model gave its best performance with a 15% test split.
# The overall accuracy reached **84%**, and the feature importance chart showed that **RAM**, **battery power**, **pixel height**, and **pixel width** played key roles in classification. The tree visualization also gives insights into how early decisions are made based on those important features.

# %% [markdown]
# ## 4.2: Random Forest Classifier (Baseline)
#
# We now train a Random Forest classifier using default parameters and test different train/test splits to compare performance

# %%
# Feature/Target split
X = train_df.drop('price_range', axis=1)
y = train_df['price_range']

# Different test sizes
test_sizes = [0.1, 0.15, 0.2, 0.25, 0.3]
accuracies_rf = {}

# %%
for size in test_sizes:
    X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=size, random_state=42, stratify=y)

    rf_model = RandomForestClassifier(random_state=42)
    rf_model.fit(X_train, y_train)

    y_pred = rf_model.predict(X_val)
    acc = accuracy_score(y_val, y_pred)
    accuracies_rf[size] = acc

    print(f"Test size = {int(size*100)}% | Accuracy = {acc:.4f}")
# Out:
# Test size = 10% | Accuracy = 0.9300
# Test size = 15% | Accuracy = 0.9167
# Test size = 20% | Accuracy = 0.8800
# Test size = 25% | Accuracy = 0.8800
# Test size = 30% | Accuracy = 0.8717

# %%
# Find best test size
best_size_rf = max(accuracies_rf, key=accuracies_rf.get)
print(f"\nBest test size for RF: {int(best_size_rf*100)}%")

# Final split and model
X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=best_size_rf, random_state=42, stratify=y)
# Out:
# Best test size for RF: 10%

# %%
best_rf_model = RandomForestClassifier(random_state=42)
best_rf_model.fit(X_train, y_train)

y_pred_best_rf = best_rf_model.predict(X_val)
